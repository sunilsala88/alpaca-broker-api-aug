# %%
from alpaca.data.historical import StockHistoricalDataClient
from datetime import datetime,timedelta
from zoneinfo import ZoneInfo

from alpaca.data.requests import StockBarsRequest ,StockTradesRequest,StockQuotesRequest
from alpaca.data.timeframe import TimeFrame, TimeFrameUnit

from alpaca.data.enums import Adjustment

api_key='PKB872RM09BHVAMWPS9P'
secret_key='yFTUvVwM5f9G0mrZJWFIZkZu5eF4mxbAq5b4wAFy'

# %%
from alpaca.trading.client import TradingClient
from alpaca.trading.requests import MarketOrderRequest
from alpaca.trading.enums import OrderSide, TimeInForce
api_key='PKB872RM09BHVAMWPS9P'
secret_key='yFTUvVwM5f9G0mrZJWFIZkZu5eF4mxbAq5b4wAFy'
trading_client = TradingClient(api_key, secret_key, paper=True)

# preparing orders
market_order_data = MarketOrderRequest(
                    symbol="SPY",
                    qty=1,
                    side=OrderSide.BUY,
                    time_in_force=TimeInForce.GTC
                    )

# Market order
market_order = trading_client.submit_order(
                order_data=market_order_data
               )

# %%
from alpaca.trading.requests import LimitOrderRequest

limit_order_data = LimitOrderRequest(
                    symbol="GOOG",
                    limit_price=164,
                    qty=1,
                    side=OrderSide.BUY,
                    time_in_force=TimeInForce.DAY
                   )

# Limit order
limit_order = trading_client.submit_order(
                order_data=limit_order_data
              )

# %%
from alpaca.trading.requests import StopOrderRequest,StopLimitOrderRequest

stop_order_data=StopOrderRequest(
                    symbol="AMZN",
                    stop_price=160,
                    qty=1,
                    side=OrderSide.SELL,
                    time_in_force=TimeInForce.DAY   
)

limit_order = trading_client.submit_order(
                order_data=stop_order_data
              )

# %%
from alpaca.trading.requests import StopLimitOrderRequest
stop_limit_order_data=StopLimitOrderRequest(
                    symbol="TSLA",
                    stop_price=210,
                    limit_price=210,
                    qty=1,
                    side=OrderSide.SELL,
                    time_in_force=TimeInForce.DAY   
)

stop_limit_order = trading_client.submit_order(
                order_data=stop_limit_order_data
              )

# %%
from alpaca.trading.requests import TrailingStopOrderRequest
trail_limit_order_data=TrailingStopOrderRequest(
                    symbol="ORCL",
                    # stop_price=415,
                    trail_percent=5,
                    qty=1,
                    side=OrderSide.SELL,
                    time_in_force=TimeInForce.DAY   
)

stop_limit_order = trading_client.submit_order(
                order_data=trail_limit_order_data
              )

# %%
# from alpaca.trading.client import TradingClient
from alpaca.trading.requests import GetOrdersRequest
from alpaca.trading.enums import OrderSide, QueryOrderStatus



# params to filter orders by
request_params = GetOrdersRequest(
                    status=QueryOrderStatus.OPEN,
                    side=OrderSide.SELL
                 )

# orders that satisfy params
orders = trading_client.get_orders(filter=request_params)
orders
# Out:
# [{   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'asset_id': UUID('27982558-2464-4daf-bb2f-b3b728659884'),
#      'canceled_at': None,
#      'client_order_id': 'a730e60b-25fd-4b66-ada7-30081871751a',
#      'created_at': datetime.datetime(2024, 8, 31, 10, 48, 5, 726513, tzinfo=TzInfo(UTC)),
#      'expired_at': None,
#      'extended_hours': False,
#      'failed_at': None,
#      'filled_at': None,
#      'filled_avg_price': None,
#      'filled_qty': '0',
#      'hwm': '141.25',
#      'id': UUID('225161d6-85e5-42f7-8236-9454071a1cb7'),
#      'legs': None,
#      'limit_price': None,
#      'notional': None,
#      'order_class': <OrderClass.SIMPLE: 'simple'>,
#      'order_type': <OrderType.TRAILING_STOP: 'trailing_stop'>,
#      'qty': '1',
#      'replaced_at': None,
#      'replaced_by': None,
#      'replaces': None,
#      'side': <OrderSide.SELL: 'sell'>,
#      'status': <OrderStatus.NEW: 'new'>,
#      'stop_price': '134.1875',
#      'submitted_at': datetime.datetime(2024, 8, 31, 10, 48, 5, 726513, tzinfo=TzInfo(UTC)),
#      'symbol': 'ORCL',
#      'time_in_force': <TimeInForce.DAY: 'day'>,
#      'trail_percent': '5',
#      'trail_price': None,
#      'type': <OrderType.TRAILING_STOP: 'trailing_stop'>,
#      'updated_at': datetime.datetime(2024, 8, 31, 10, 48, 5, 728536, tzinfo=TzInfo(UTC))},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'asset_id': UUID('21d40833-6d13-4031-9af3-02f6a516d791'),
#      'canceled_at': None,
#      'client_order_id': 'dab3d796-80f7-4217-90f0-149212aa75a2',
#      'created_at': datetime.datetime(2024, 8, 31, 10, 46, 45, 865531, tzinfo=TzInfo(UTC)),
#      'expired_at': None,
#      'extended_hours': False,
#      'failed_at': None,
#      'filled_at': None,
#      'filled_avg_price': None,
#      'filled_qty': '0',
#      'hwm': '202.13',
#      'id': UUID('56218d44-cb72-4af6-b2ef-36216e63881c'),
#      'legs': None,
#      'limit_price': None,
#      'notional': None,
#      'order_class': <OrderClass.SIMPLE: 'simple'>,
#      'order_type': <OrderType.TRAILING_STOP: 'trailing_stop'>,
#      'qty': '1',
#      'replaced_at': None,
#      'replaced_by': None,
#      'replaces': None,
#      'side': <OrderSide.SELL: 'sell'>,
#      'status': <OrderStatus.NEW: 'new'>,
#      'stop_price': '197.13',
#      'submitted_at': datetime.datetime(2024, 8, 31, 10, 46, 45, 865531, tzinfo=TzInfo(UTC)),
#      'symbol': 'IBM',
#      'time_in_force': <TimeInForce.DAY: 'day'>,
#      'trail_percent': None,
#      'trail_price': '5',
#      'type': <OrderType.TRAILING_STOP: 'trailing_stop'>,
#      'updated_at': datetime.datetime(2024, 8, 31, 10, 46, 45, 867442, tzinfo=TzInfo(UTC))},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'asset_id': UUID('b6d1aa75-5c9c-4353-a305-9e2caa1925ab'),
#      'canceled_at': None,
#      'client_order_id': '95ac046d-7ea8-432b-9da7-a74a9f98be07',
#      'created_at': datetime.datetime(2024, 8, 31, 10, 45, 3, 502746, tzinfo=TzInfo(UTC)),
#      'expired_at': None,
#      'extended_hours': False,
#      'failed_at': None,
#      'filled_at': None,
#      'filled_avg_price': None,
#      'filled_qty': '0',
#      'hwm': '417.2',
#      'id': UUID('3afe43ab-40eb-4f01-8c95-ae62d3b0576c'),
#      'legs': None,
#      'limit_price': None,
#      'notional': None,
#      'order_class': <OrderClass.SIMPLE: 'simple'>,
#      'order_type': <OrderType.TRAILING_STOP: 'trailing_stop'>,
#      'qty': '1',
#      'replaced_at': None,
#      'replaced_by': None,
#      'replaces': None,
#      'side': <OrderSide.SELL: 'sell'>,
#      'status': <OrderStatus.NEW: 'new'>,
#      'stop_price': '412.2',
#      'submitted_at': datetime.datetime(2024, 8, 31, 10, 45, 3, 502746, tzinfo=TzInfo(UTC)),
#      'symbol': 'MSFT',
#      'time_in_force': <TimeInForce.DAY: 'day'>,
#      'trail_percent': None,
#      'trail_price': '5',
#      'type': <OrderType.TRAILING_STOP: 'trailing_stop'>,
#      'updated_at': datetime.datetime(2024, 8, 31, 10, 45, 3, 504464, tzinfo=TzInfo(UTC))},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'asset_id': UUID('8ccae427-5dd0-45b3-b5fe-7ba5e422c766'),
#      'canceled_at': None,
#      'client_order_id': '78f93d87-16bc-4f99-9e63-f5d4e311ff60',
#      'created_at': datetime.datetime(2024, 8, 31, 10, 21, 34, 517647, tzinfo=TzInfo(UTC)),
#      'expired_at': None,
#      'extended_hours': False,
#      'failed_at': None,
#      'filled_at': None,
#      'filled_avg_price': None,
#      'filled_qty': '0',
#      'hwm': None,
#      'id': UUID('5364c3c0-3ebf-461c-bde7-f04d1da54734'),
#      'legs': None,
#      'limit_price': '210',
#      'notional': None,
#      'order_class': <OrderClass.SIMPLE: 'simple'>,
#      'order_type': <OrderType.STOP_LIMIT: 'stop_limit'>,
#      'qty': '1',
#      'replaced_at': None,
#      'replaced_by': None,
#      'replaces': None,
#      'side': <OrderSide.SELL: 'sell'>,
#      'status': <OrderStatus.ACCEPTED: 'accepted'>,
#      'stop_price': '210',
#      'submitted_at': datetime.datetime(2024, 8, 31, 10, 21, 34, 517647, tzinfo=TzInfo(UTC)),
#      'symbol': 'TSLA',
#      'time_in_force': <TimeInForce.DAY: 'day'>,
#      'trail_percent': None,
#      'trail_price': None,
#      'type': <OrderType.STOP_LIMIT: 'stop_limit'>,
#      'updated_at': datetime.datetime(2024, 8, 31, 10, 21, 34, 518785, tzinfo=TzInfo(UTC))},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'asset_id': UUID('f801f835-bfe6-4a9d-a6b1-ccbb84bfd75f'),
#      'canceled_at': None,
#      'client_order_id': '25e74420-4491-4fe2-a52c-9d17e8584f81',
#      'created_at': datetime.datetime(2024, 8, 31, 10, 16, 8, 956362, tzinfo=TzInfo(UTC)),
#      'expired_at': None,
#      'extended_hours': False,
#      'failed_at': None,
#      'filled_at': None,
#      'filled_avg_price': None,
#      'filled_qty': '0',
#      'hwm': None,
#      'id': UUID('eb3b6633-56d7-4d8c-ab06-82e57dd14e17'),
#      'legs': None,
#      'limit_price': None,
#      'notional': None,
#      'order_class': <OrderClass.SIMPLE: 'simple'>,
#      'order_type': <OrderType.STOP: 'stop'>,
#      'qty': '1',
#      'replaced_at': None,
#      'replaced_by': None,
#      'replaces': None,
#      'side': <OrderSide.SELL: 'sell'>,
#      'status': <OrderStatus.ACCEPTED: 'accepted'>,
#      'stop_price': '160',
#      'submitted_at': datetime.datetime(2024, 8, 31, 10, 16, 8, 956362, tzinfo=TzInfo(UTC)),
#      'symbol': 'AMZN',
#      'time_in_force': <TimeInForce.DAY: 'day'>,
#      'trail_percent': None,
#      'trail_price': None,
#      'type': <OrderType.STOP: 'stop'>,
#      'updated_at': datetime.datetime(2024, 8, 31, 10, 16, 8, 957280, tzinfo=TzInfo(UTC))}]

# %%
import pandas as pd
ord_df=pd.DataFrame([dict(position) for position in orders])
ord_df
# Out:
#                                      id                       client_order_id  \
# 0  225161d6-85e5-42f7-8236-9454071a1cb7  a730e60b-25fd-4b66-ada7-30081871751a
# 1  56218d44-cb72-4af6-b2ef-36216e63881c  dab3d796-80f7-4217-90f0-149212aa75a2
# 2  3afe43ab-40eb-4f01-8c95-ae62d3b0576c  95ac046d-7ea8-432b-9da7-a74a9f98be07
# 3  5364c3c0-3ebf-461c-bde7-f04d1da54734  78f93d87-16bc-4f99-9e63-f5d4e311ff60
# 4  eb3b6633-56d7-4d8c-ab06-82e57dd14e17  25e74420-4491-4fe2-a52c-9d17e8584f81
#
#                         created_at                       updated_at  \
# 0 2024-08-31 10:48:05.726513+00:00 2024-08-31 10:48:05.728536+00:00
# 1 2024-08-31 10:46:45.865531+00:00 2024-08-31 10:46:45.867442+00:00
# 2 2024-08-31 10:45:03.502746+00:00 2024-08-31 10:45:03.504464+00:00
# 3 2024-08-31 10:21:34.517647+00:00 2024-08-31 10:21:34.518785+00:00
# 4 2024-08-31 10:16:08.956362+00:00 2024-08-31 10:16:08.957280+00:00
#
#                       submitted_at filled_at expired_at canceled_at failed_at  \
# 0 2024-08-31 10:48:05.726513+00:00      None       None        None      None
# 1 2024-08-31 10:46:45.865531+00:00      None       None        None      None
# 2 2024-08-31 10:45:03.502746+00:00      None       None        None      None
# 3 2024-08-31 10:21:34.517647+00:00      None       None        None      None
# 4 2024-08-31 10:16:08.956362+00:00      None       None        None      None
#
#   replaced_at  ...            side    time_in_force limit_price stop_price  \
# 0        None  ...  OrderSide.SELL  TimeInForce.DAY        None   134.1875
# 1        None  ...  OrderSide.SELL  TimeInForce.DAY        None     197.13
# 2        None  ...  OrderSide.SELL  TimeInForce.DAY        None      412.2
# 3        None  ...  OrderSide.SELL  TimeInForce.DAY         210        210
# 4        None  ...  OrderSide.SELL  TimeInForce.DAY        None        160
#
#                  status extended_hours  legs trail_percent trail_price     hwm
# 0       OrderStatus.NEW          False  None             5        None  141.25
# 1       OrderStatus.NEW          False  None          None           5  202.13
# 2       OrderStatus.NEW          False  None          None           5   417.2
# 3  OrderStatus.ACCEPTED          False  None          None        None    None
# 4  OrderStatus.ACCEPTED          False  None          None        None    None
#
# [5 rows x 32 columns]
